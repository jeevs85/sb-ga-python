# %%
playlist = [
    {
        'title': 'Bodak Yellow',
        'genre': 'Pop',
        'artiste': 'Cardi B',
        'year': '2017',
        'length': 3.25
    },
    {
        'title': 'Shake it Off',
        'genre': 'Pop',
        'artiste': 'Taylor Swift',
        'year': '2016',
        'length': 3.15
    },
    {
        'title': 'Through the Night',
        'genre': 'Pop',
        'artiste': 'Travis Scott',
        'year': '2016',
        'length': 4.50
    },
    {
        'title': 'Likes',
        'genre': 'Reggae',
        'artiste': 'Chronixx',
        'year': '2017',
        'length': 3.45
    },
    {
        'title': 'From Time',
        'genre': 'Pop',
        'artiste': 'Drake, Jhene Aiko',
        'year': '2013',
        'length': 2.50
    }
]

# %%
# use the playlist to write these functions 

#1. write a function that returns a list of the artists names

#2. Write a function that returns the longest rnning song

#3. WRite a function that returns the total runnting time of the playlist

playlist = [
    {
        'title': 'Bodak Yellow',
        'genre': 'Pop',
        'artiste': 'Cardi B',
        'year': '2017',
        'length': 3.25
    },
    {
        'title': 'Shake it Off',
        'genre': 'Pop',
        'artiste': 'Taylor Swift',
        'year': '2016',
        'length': 3.15
    },
    {
        'title': 'Through the Night',
        'genre': 'Pop',
        'artiste': 'Travis Scott',
        'year': '2016',
        'length': 4.50
    },
    {
        'title': 'Likes',
        'genre': 'Reggae',
        'artiste': 'Chronixx',
        'year': '2017',
        'length': 3.45
    },
    {
        'title': 'From Time',
        'genre': 'Pop',
        'artiste': 'Drake, Jhene Aiko',
        'year': '2013',
        'length': 4
    }
]
def get_LongestSong(a_dict):
    title = ''
    longest = -1
    for name in a_dict:
        if name['length'] > longest :
            longest = name['length']
            title = name['title']

    return title

def get_artist (a_dict): 
    artistname = []

    for name in a_dict:
        artistname.append(name['artiste'])
    return artistname

def get_totalRunTime (a_dict):
    total = 0

    for name in a_dict:
        total += name['length']
    return total

print(get_artist(playlist))
print(get_LongestSong(playlist) )
print(get_totalRunTime(playlist))
# Out:
# ['Cardi B', 'Taylor Swift', 'Travis Scott', 'Chronixx', 'Drake, Jhene Aiko']
# Through the Night
# 18.35

# %%
def create_phone_number(n):
    counter = 0
    number = ''
    for num in n:
        if counter == 0:
            number +='('
            counter +=1
        elif counter ==4:
            number +=') '
            counter +=1
        elif counter ==8 :
            number +='-'
        number += str(num)
        counter +=1
    return number

nums = [1,2,4,5,6,7,8,9,0,3]

def create2 (n):
    str = "".join(map(str,n))
    return f"({_str[:3]}) {_str[3:6]}-{_str[6:]}"


create2(nums)
# Out:
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# c:\Users\jeevs\Documents\pythonCourse\Week-3\extra.ipynb Cell 3' in <cell line: 24>()
#      <a href='vscode-notebook-cell:/c%3A/Users/jeevs/Documents/pythonCourse/Week-3/extra.ipynb#ch0000002?line=19'>20</a>     str = "".join(map(str,n))
#      <a href='vscode-notebook-cell:/c%3A/Users/jeevs/Documents/pythonCourse/Week-3/extra.ipynb#ch0000002?line=20'>21</a>     return f"({_str[:3]}) {_str[3:6]}-{_str[6:]}"
# ---> <a href='vscode-notebook-cell:/c%3A/Users/jeevs/Documents/pythonCourse/Week-3/extra.ipynb#ch0000002?line=23'>24</a> create2(nums)
#
# c:\Users\jeevs\Documents\pythonCourse\Week-3\extra.ipynb Cell 3' in create2(n)
#      <a href='vscode-notebook-cell:/c%3A/Users/jeevs/Documents/pythonCourse/Week-3/extra.ipynb#ch0000002?line=18'>19</a> def create2 (n):
# ...
