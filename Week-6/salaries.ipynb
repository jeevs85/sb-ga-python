# %%
import pandas as pd


data = pd.read_csv("Salaries.csv")
#show the number of rows and columns
data.shape
data.columns


data['Benefits'].isnull().sum()
# Out:
# 36163

# %%
#describe the data
data.describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148654.000000  148045.000000  148650.000000  148650.000000
# mean    74327.500000   66325.448840    5066.059886    3648.767297
# std     42912.857795   42764.635495   11454.380559    8056.601866
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37164.250000   33588.200000       0.000000       0.000000
# 50%     74327.500000   65007.450000       0.000000     811.270000
# 75%    111490.750000   94691.050000    4658.175000    4236.065000
# max    148654.000000  319275.010000  245131.880000  400184.250000
#
#             Benefits       TotalPay  TotalPayBenefits           Year  Notes  \
# count  112491.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    25007.893151   74768.321972      93692.554811    2012.522643    NaN
# std     15402.215858   50517.005274      62793.533483       1.117538    NaN
# ...

# %%
#show the data types 

data.dtypes
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %%
data.shape

#filter base pay greater than 80
data2 = data[data['BasePay'] > 80000]

#any operation that produces a data frame can then be 

#data2[['EmployeeName','JobTitle']]

data[data['BasePay'] > 80000][['EmployeeName','JobTitle']]
# Out:
#              EmployeeName                                        JobTitle
# 0          NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1            GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2          ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 4         PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
# 5          DAVID SULLIVAN                       ASSISTANT DEPUTY CHIEF II
# ...                   ...                                             ...
# 132173    Ying Hang Zhang                                   Special Nurse
# 132254     Chinelo V Amah                                   Special Nurse
# 132324    Mariela B Badum                                   Special Nurse
# 132799  Judith A Boyajian                      Assistant Chief Attorney 1
# 133856    Mary Ann M Hauf                                   Special Nurse
#
# [51785 rows x 2 columns]

# %%
#multiple conditions 
#base pay greater than 80k and from the san fran agency
data[(data['BasePay']>80000) &(data['Year'] =='San Francisco')]
#data[data['BasePay'] > 80000][data['Year'] == '2014']
#data[(data['BasePay'] > 80000) & ([data['BasePay'] > 80000]) ]


#Looking at categorcal data 
#how many agencies are there? 

#data['JobTitle'].value_counts()
# Out:
# Empty DataFrame
# Columns: [Id, EmployeeName, JobTitle, BasePay, OvertimePay, OtherPay, Benefits, TotalPay, TotalPayBenefits, Year, Notes, Agency, Status]
# Index: []

# %%
#value_counts() does not work on dataframes
