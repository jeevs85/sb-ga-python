# %%
#create dataframe
import pandas as pd

data = {'Make': ['Toyota', 'Lexus', 'BMW', 'Hyundai'], "Model": ['Rav 4', 'Ls20', 'X3', 'Elantra'], 'Year':[2018, 2015, 2012, 2022]}

cars = pd.DataFrame(data)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# c:\Users\jeevs\Documents\pythonCourse\Week-7\joins.ipynb Cell 1 in <cell line: 2>()
#       <a href='vscode-notebook-cell:/c%3A/Users/jeevs/Documents/pythonCourse/Week-7/joins.ipynb#ch0000000?line=0'>1</a> #create dataframe
# ----> <a href='vscode-notebook-cell:/c%3A/Users/jeevs/Documents/pythonCourse/Week-7/joins.ipynb#ch0000000?line=1'>2</a> import pandas as pd
#       <a href='vscode-notebook-cell:/c%3A/Users/jeevs/Documents/pythonCourse/Week-7/joins.ipynb#ch0000000?line=3'>4</a> data = {'Make': ['Toyota', 'Lexus', 'BMW', 'Hyundai'], "Model": ['Rav 4', 'Ls20', 'X3', 'Elantra'], 'Year':[2018, 2015, 2012, 2022]}
#       <a href='vscode-notebook-cell:/c%3A/Users/jeevs/Documents/pythonCourse/Week-7/joins.ipynb#ch0000000?line=5'>6</a> cars = pd.DataFrame(data)
#
# ModuleNotFoundError: No module named 'pandas'

# %%
cars
# Out:
#       Make    Model  Year
# 0   Toyota    Rav 4  2018
# 1    Lexus     Ls20  2015
# 2      BMW       X3  2012
# 3  Hyundai  Elantra  2022

# %%
moreData = {'Make': ['Toyota', 'Lexus', 'BMW', 'Hyundai'], "Model": ['Corolla', 'Ls200', 'M3', 'Sonata'], 'Year':[2018, 2015, 2012, 2022]}
moreCars = pd.DataFrame(moreData)

pd.concat([cars,moreCars])
# Out:
#       Make    Model  Year
# 0   Toyota    Rav 4  2018
# 1    Lexus     Ls20  2015
# 2      BMW       X3  2012
# 3  Hyundai  Elantra  2022
# 0   Toyota  Corolla  2018
# 1    Lexus    Ls200  2015
# 2      BMW       M3  2012
# 3  Hyundai   Sonata  2022

# %%
price_data = {'Price': [25000, 50000, 54000, 27000], 'Seats': [5, 5, 5, 5]}

prices = pd.DataFrame(price_data)

pd.concat([cars, prices], axis=1)
# Out:
#       Make    Model  Year  Price  Seats
# 0   Toyota    Rav 4  2018  25000      5
# 1    Lexus     Ls20  2015  50000      5
# 2      BMW       X3  2012  54000      5
# 3  Hyundai  Elantra  2022  27000      5

# %%
# to get the actor data for movies, join the movies and actors dataframes

movies = pd.read_csv("movies.csv")
actors = pd.read_csv("actors.csv")

pd.merge(movies, actors, how= 'right', on='movie_id')
# Out:
#    movie_id              title    genre  rating   release_year   movie_id  \
# 0         1  Lord of The Rings  Fantasy      PG           2015          3
# 1         2            Memento    Drama    PG13           2001          2
#
#              name   age  sex
# 0   Russell Crowe    55    M
# 1      Guy Pierce    57   M

# %%
pd.merge(movies, actors, how= 'left', on='movie_id')
# Out:
#    movie_id                           title    genre  rating   release_year  \
# 0         1               Lord of The Rings  Fantasy      PG           2015
# 1         2                         Memento    Drama    PG13           2001
# 2         3                A Beautiful Mind    Drama      PG            208
# 3         4                       Gladiator    Drama    PG13           2007
# 4         5        Pirates of The Caribbean  Fantasy      PG           2014
# 5         6             Legends of The Fall    Drama    PG13           1999
# 6         7                  Pan's Labrynth  Fantasy      PG           2004
# 7         8  The Boy in the Striped Pajamas    Drama    PG13           2009
# 8         9                Schindler's List    Drama    PG13           2000
# 9        10            Shawshank Redemption    Drama    PG13           1989
#
#     movie_id            name   age  sex
# 0        3.0   Russell Crowe  55.0    M
# 1        2.0      Guy Pierce  57.0   M
# 2        NaN             NaN   NaN  NaN
# 3        NaN             NaN   NaN  NaN
# 4        NaN             NaN   NaN  NaN
# 5        NaN             NaN   NaN  NaN
# 6        NaN             NaN   NaN  NaN
# 7        NaN             NaN   NaN  NaN
# 8        NaN             NaN   NaN  NaN
# 9        NaN             NaN   NaN  NaN
